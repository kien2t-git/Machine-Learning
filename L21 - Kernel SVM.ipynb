# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm

X = np.c_[(0, 0), (1, 1), (1, 0), (0, 1)].T
N = 2
Y = [0]*N + [1]*N

# %%
def myplot(clf):
    fig, ax = plt.subplots()
    plt.clf()
    
    x_min, x_max = X[:, 0].min()-1, X[:, 0].max()+1
    y_min, y_max = X[:, 1].min()-1, X[:, 1].max()+1
    
    plt.figure(figsize=(6, 5))
    plt.scatter(clf.support_vectors_[:, 0], clf.support_vectors_[:, 1], s=80, facecolors='None')
    
    XX, YY = np.mgrid[x_min:x_max:200j, y_min:y_max:200j]
    Z = clf.decision_function(np.c_[XX.ravel(), YY.ravel()])
    
    Z = Z.reshape(XX.shape)
    
    plt.contourf(XX, YY, np.sign(Z), 200, cmap='jet', alpha =.2)
    plt.contour(XX, YY, Z, colors=['k', 'k', 'k'], linestyles=['--', '--', '--'], levels=[-.5, 0, .5])
    
    plt.plot(X[:N, 0], X[:N, 1], 'bo', markersize=8)
    plt.plot(X[N:, 0], X[N:, 1], 'rs', markersize=8)
    plt.xlim(x_min, x_max)
    plt.ylim(y_min, y_max)

# %%
for kernel in ('sigmoid', 'poly', 'rbf'):
    clf = svm.SVC(kernel=kernel, gamma=4, coef0=0)
    clf.fit(X, Y)
    myplot(clf)
    plt.title(kernel, fontsize=15)
plt.show()

# %%
X = np.c_[(-1, -3),
           (0, -2),
           (1, -2),
           (2, 1),
           (3, 0),
           (1.5, 1.4),
           #---
           (1, 3),
           (0.5, -1),
           (-1, 2),
           (-2, -1.5),
           (-2, 0),
           (-1.5, -1.2)].T
N = 6
Y = [0]*N + [1]*N

# %%
for kernel in ('sigmoid', 'poly', 'rbf'):
    clf = svm.SVC(kernel=kernel, gamma=1, coef0=1)
    clf.fit(XX, YY)
    myplot(clf)
    plt.title(kernel, fontsize=15)
plt.show()
